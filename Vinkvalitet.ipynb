# %%
import pandas as pd
import pylab as py
import matplotlib.pyplot as plt

# %%
vin = pd.read_csv("vin.csv")

# %%
vin.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %% [markdown]
# ### Her er datasettet vårt!
# Her har vi fått sett forskjellige variabler som vi skal sammenligne. Vi har importert eventuelle pakker vi skal bruke.

# %%
vin.pop("density")
# Out:
# 0       0.99780
# 1       0.99680
# 2       0.99700
# 3       0.99800
# 4       0.99780
# 5       0.99780
# 6       0.99640
# 7       0.99460
# 8       0.99680
# 9       0.99780
# 10      0.99590
# 11      0.99780
# 12      0.99430
# 13      0.99740
# 14      0.99860
# 15      0.99860
# 16      0.99690
# 17      0.99680
# 18      0.99740
# 19      0.99690
# 20      0.99680
# 21      0.99820
# 22      0.99660
# 23      0.99680
# 24      0.99680
# 25      0.99550
# 26      0.99620
# 27      0.99660
# 28      0.99720
# 29      0.99640
#          ...
# 1569    0.99396
# 1570    0.99340
# 1571    0.99514
# 1572    0.99632
# 1573    0.99467
# 1574    0.99677
# 1575    0.99474
# 1576    0.99588
# 1577    0.99622
# 1578    0.99540
# 1579    0.99402
# 1580    0.99470
# 1581    0.99402
# 1582    0.99362
# 1583    0.99578
# 1584    0.99484
# 1585    0.99494
# 1586    0.99492
# 1587    0.99483
# 1588    0.99414
# 1589    0.99770
# 1590    0.99314
# 1591    0.99402
# 1592    0.99574
# ...

# %%
vin.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide    pH  sulphates  alcohol  \
# 0                 11.0                  34.0  3.51       0.56      9.4
# 1                 25.0                  67.0  3.20       0.68      9.8
# 2                 15.0                  54.0  3.26       0.65      9.8
# 3                 17.0                  60.0  3.16       0.58      9.8
# 4                 11.0                  34.0  3.51       0.56      9.4
#
#    quality
# 0        5
# 1        5
# 2        5
# 3        6
# 4        5

# %% [markdown]
# ### Datasettet vårt nå:
# Her har vi fjernet tetthet fra datasettet vårt fordi vi ikke så noen som helst sammenhenger mellom denne faktoren og kvaliteten når vi studerte datasettet manuellt.

# %%
vin.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide           pH  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     3.311113
# std       0.047065            10.460157             32.895324     0.154386
# ...

# %% [markdown]
# ### Hva ser vi her?
#
# Vi ser ut i fra dette at det er 1599 verdier i hver kolonne. Her kan vi også blant annet lese av gjennomsnitt (mean), standard avvik (std) og minste verdi (min) og største verdi (max).

# %%
vin.sort_values("residual sugar")
vin.sort_values("quality")
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1478            7.1             0.875         0.05            5.70      0.082
# 832            10.4             0.440         0.42            1.50      0.145
# 899             8.3             1.020         0.02            3.40      0.084
# 1374            6.8             0.815         0.00            1.20      0.267
# 459            11.6             0.580         0.66            2.20      0.074
# 517            10.4             0.610         0.49            2.10      0.200
# 1469            7.3             0.980         0.05            2.10      0.061
# 690             7.4             1.185         0.00            4.25      0.097
# 1505            6.7             0.760         0.02            1.80      0.078
# 1299            7.6             1.580         0.00            2.10      0.137
# 724             7.5             1.115         0.10            3.10      0.086
# ...

# %% [markdown]
# ### Datasettet vårt nå:
#
# Her forsøkte vi å sortere noen av variablene, for å se om det gjorde datasettet vårt noe enkelere.
# ###### Det gjorde ikke det...

# %%
vin.plot("fixed acidity","quality")

# %% [markdown]
# ### Dette gir meg Vietnam flashbacks

# %%
vin.plot("fixed acidity","quality", style = ".")

# %% [markdown]
# ### Det her hjalp heller ikke veldig mye:

# %%
vin.plot("quality",style = ".")

# %% [markdown]
# # Her snur ting:
#
# ### Vi tok boxplot av alle variablene mot kvaliteten.
# Her fikk vi leselige plot, som kan vise korrelasjonen eller kausaliteten til de forskjellige variablene våre.

# %%
vin.boxplot("fixed acidity","quality")

# %% [markdown]
# Ut ifra dette plottet ser vi verken korrelasjon eller kausalitet mellom 'fixed acidity' og kavilteten.

# %%
vin.boxplot("volatile acidity","quality")

# %% [markdown]
# Her derimot ser vi godt at 'volatile acidity' burde være så lav som mulig for å øke kvaliteten. Dette kommer av at dette er flyktige gasser der lukten og smaken assosieres med eddik, noe som ikke er gunstig for å få viner med høy kvalitet.

# %%
vin.boxplot("citric acid","quality")

# %% [markdown]
# Her ser vi at 'citric acid' burde  være så høy som mulig. Dette tror vi har å gjøre med at dette er en frisk syrlig smak som er gunstig for vinene.

# %%
vin.boxplot("residual sugar","quality")

# %% [markdown]
# Vi ser ikke noen tydelige sammenhenger her, men vi kan se at vinene med høyest kvalitet ikke har så høyt sukkerinnhold.

# %%
vin.boxplot("chlorides","quality")

# %% [markdown]
# Her ser vi tydelig at lavt innhold av klorider fører til høy kvalitet. Her ser vi altså kausalitet. Kloridene finner vi i NaCl noe som vil føre til mye smak av salt, og dette er tydeligvis ikke gunstig for viner.

# %%
vin.boxplot("free sulfur dioxide","quality")

# %% [markdown]
# Vi gjorde litt research om 'sulphur dioxide' og fant ut at dette forhindrer at vinen oksiderer. Den kan likevel sette vond smak på vinen dersom det er for store mengder i vinen. For små mengder vil i noen tilfeller føre til at vinen oksiderer og blir dårlig, og det er dette vi ser eksempler på der vinen har lavest kvalitet. De vinene som har høyest kvalitet har altså ikke oksidert og blitt dårlig, og ikke fått dårlig smak av 'sulphur dioxides'. 'Free sulphur dioxide' er omgjort til gass og merkes dermed som vond lukt.

# %%
vin.boxplot("total sulfur dioxide","quality")

# %% [markdown]
# Vi ser det samme her som på plottet ovenfor. Her får vi derimot også med svoveldioksidet som er i væskefase.

# %%
vin.boxplot("pH","quality")

# %% [markdown]
# Vi ser ut ifra dette plottet at lav pH gir høyere kvalitet. Dette er sannsynligvis fordi surhetssmaken da er lavere og oppfattes bedre.

# %%
vin.boxplot("sulphates","quality")

# %% [markdown]
# Sulfater, ser vi ut ifra dette plottet, i likhet med 'sulphur dioxides' o.l. at er bra for vinen i små mengder ettersom det ifølge researchen vi gjorde øker holdbarheten(vinen oksiderer ikke), men at smaken på selve stoffet ikke nødvendigvis er bra for vinen i for store mengder.

# %%
vin.boxplot("alcohol","quality")

# %%
Vi ser at lokoholprosenten bør være så høy som mulig dersom vi plotter den også mot kvaliteten.

# %% [markdown]
# Vi ser ut ifra disse boxplottene at for å få høy kvalitet burde man ha lav 'volatile acidity', høy 'citric acid', ikke for høyt innhold av 'residual sugars', lavt innhold av 'chlorides', lav pH og høy alkoholprosent. 'sulphates'og 'sulphur dioxides' har dårlig smak og bør derfor ikke være for høyt, men øker holdbarheten og friskheten i vinen. Vi ser derfor korrelasjon mellom lavt innhold av disse og høy kvalitet, men det er ikke kausalitet ettersom vinene med lavest kvalitet har lavt innhold av 'sulphates'og 'sulphur dioxides' og dermed har blitt 'dårlige' som følge av oksidasjon av vinen.

# %% [markdown]
# # Maskinlæring:

# %%
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn import tree
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.externals.six import StringIO

# %%
qualitymap = {range(0,5):0,range(5,10):1}
vin["quality"] = vin["quality"].map(qualitymap)

# %%
features=vin[['volatile acidity','citric acid','chlorides','sulphates','alcohol']]
labels=vin['quality']

# %%
features_trn, features_tst, labels_trn, labels_tst = train_test_split(features, labels, test_size=0.33, random_state=42)

# %% [markdown]
# Dette var så langt vi kom med maskinlæringen fra Bouvet. Vi fikk en feilmelding når vi forsøkte å bruke kommandoene:
# dt = tree.DecisionTreeClassifier()
# dt.fit(features_trn, labels_trn)
# Ideen vår var at vi definerte kvaliteten 0 til og med 4 som dårlig, og fra 5 til 10 som bra. Deretter var planen å bruke samme idé som vi gjorde på fagdagen for å lage et "decision tree" med de forskjellige verdiene vi tidligere har funnet ut at er svært relevante for kvaliteten. Treet skulle, i likhet med det vi lagde for titanic, si om vinen ville være god eller dårlig med informasjonen det fikk.
# Vi fikk dessverre ikke tid til å ferdigstille dette, men vi har likevel svart på det oppgaven spurte om.
